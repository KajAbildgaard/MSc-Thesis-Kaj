# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# %%
def load_data(base_path, scenario):
    data = {}
    prod_root = os.path.join(base_path, scenario)

    for scenario in os.listdir(prod_root):
        scenario_path = os.path.join(prod_root, scenario)
        if not os.path.isdir(scenario_path):
            continue

        # break off q and WR
        parts = [p.strip() for p in scenario.split(',')]
        q_value  = parts[0]                   # 'q=0' or 'q=3.1e-07'
        well_rate = parts[1] if len(parts)>1 else ''  # 'WR=8000'

        for model_dir in os.listdir(scenario_path):
            model_path = os.path.join(scenario_path, model_dir)
            if not os.path.isdir(model_path):
                continue

            mp = [p.strip() for p in model_dir.split(',')]
            model_name = mp[0]                # 'homogeneous' or 'model 0'
            q_key = q_value
            if len(mp)>1:
                q_key += f', {mp[1]}'         # add 'dir=…' if present

            fname = os.path.join(model_path, 'time_data.xlsx')
            df = pd.read_excel(fname, usecols=['time','PRD : temperature (K)', 'INJ : temperature (K)', 
                                               'PRD : BHP (bar)', 'INJ : BHP (bar)'])
            data.setdefault(model_name, {})[(q_key, well_rate)] = df

    return data

def plot_collection(data, q_value, well_rate, diff=False, x_limits: tuple[float,float]=None):
    models   = ['homogeneous','model 0','model 1','model 2','model 3','model 4']
    fig, axes = plt.subplots(3,2,figsize=(14,11), sharex=False, sharey=True)
    axes = axes.flatten()
    base_key = 'q=0'

    angle_groups = [
        [0], [45,315], [90,270], [135,225], [180]
    ]
    tab10 = plt.get_cmap('tab10').colors
    group_colors = tab10[:5]
    style_map = {}
    for idx, grp in enumerate(angle_groups):
        col = group_colors[idx]
        for a in grp:
            style_map[a] = (col, '-')
    for a in [315,270,225,180]:
        c,_ = style_map[a]
        style_map[a] = (c, '--')

    for ax, model in zip(axes, models):
        series = {
            qk:df for (qk,wr),df in data.get(model, {}).items()
            if wr == well_rate
        }

        if diff:
            df0 = series.get(base_key)
            t0, T0 = df0['time'].values, df0['PRD : temperature (K)'].values

        for qk in sorted(series, key=legend_sort):
            if diff:
                if qk == base_key or not qk.startswith(q_value):
                    continue
            else:
                if not (qk == base_key or qk.startswith(q_value)):
                    continue

            df = series[qk]
            t  = df['time'].values / 365
            y  = df['PRD : temperature (K)'].values
            if qk == base_key:
                ax.plot(t, y, label=qk,
                        linestyle='-.', color='black')
            else:
                angle = int(qk.split('dir=')[1])
                col, ls = style_map[angle]
                if diff:
                    y = y - np.interp(df['time'].values, t0, T0)
                ax.plot(t, y, label=qk,
                        color=col, linestyle=ls)

        if x_limits is not None:
            ax.set_xlim(*x_limits)

        ax.set_title(model)
        ax.grid(True)

    handles, labels = axes[0].get_legend_handles_labels()
    hm = dict(zip(labels, handles))
    # m/s to m/day
    if q_value == 'q=2.3e-08':
        q_new = 'q=0.002'
    if q_value == 'q=2.3e-07':
        q_new = 'q=0.020'
    if q_value == 'q=1.15e-07':
        q_new = 'q=0.010'
    if q_value == 'q=3.1e-07':
        q_new = 'q=0.027'

    hm_converted = {}
    for k, v in hm.items():
        if k.startswith(q_value):
            hm_converted[k.replace(q_value, q_new)] = v
        else:
            hm_converted[k] = v

    hm = hm_converted

    left  = [
        f"{q_new}, dir=0",
        f"{q_new}, dir=45",
        f"{q_new}, dir=90",
        f"{q_new}, dir=135",
        "q=0" if not diff else ""
    ]
    right = [
        "",
        f"{q_new}, dir=315",
        f"{q_new}, dir=270",
        f"{q_new}, dir=225",
        f"{q_new}, dir=180"
    ]
    blank = Line2D([],[],linestyle='none',color='none')
    lh, ll = [], []
    for lab in left + right:
        if lab:
            lh.append(hm.get(lab, blank))
            ll.append(lab)
        else:
            lh.append(blank)
            ll.append("")

    fig.legend(
        lh, ll,
        title='Background flowrate, direction',
        ncol=2,
        loc='center left',
        bbox_to_anchor=(0.92,0.5),
        borderaxespad=0.0,
        handlelength=2,
        handletextpad=0.5
    )

    kind = 'PRD : Temperature Difference' if diff else 'PRD : Temperature'
    fig.suptitle(f"{kind} vs Time: {q_new} m/day, {well_rate} m³/day", fontsize=14)
    fig.text(0.5, 0.04, 'Time (years)', ha='center')
    ylabel = r'$\Delta T$ (K) relative to q=0' if diff else 'PRD : temperature (K)'
    fig.text(0.04, 0.5, ylabel, va='center', rotation='vertical')

    fig.tight_layout(rect=[0.05,0.05,0.88,0.93])
    plt.show()

def legend_sort(q_key):
    if q_key.startswith("q=0"):
        return (0, 0)
    if "dir=" in q_key:
        angle_part = q_key.split("dir=", 1)[1]
        angle_str = angle_part.split()[0].rstrip(",")
        return (1, int(angle_str))
    return (1, -1)

def compute_lifetimes(data):
    lifetimes = {}
    for model, series_dict in data.items():
        for (q_key, wr), df in series_dict.items():
            if ', ' in q_key:
                q_value, dir_part = q_key.split(', ', 1)
                direction = dir_part.split('=')[1]
            else:
                q_value, direction = q_key, '0'
            T0 = df['PRD : temperature (K)'].iloc[0]
            thresh = T0 - 0.15 * (T0 - 300)

            # find first time below threshold
            below = df['PRD : temperature (K)'] <= thresh
            if below.any():
                t_first = df.loc[below, 'time'].iloc[0]
                life_years = int(t_first / 365)  # floor to whole years
            else:
                life_years = pd.NA
            lifetimes.setdefault(wr, {}) \
                     .setdefault(q_value, {}) \
                     .setdefault(model, {})[direction] = life_years
    return lifetimes

def lifetime_tables(data):
    lifetimes = compute_lifetimes(data)
    models     = ['homogeneous','model 0','model 1','model 2','model 3','model 4']
    directions = ['0','45','90','135','180','225','270','315']

    for wr in sorted(lifetimes.keys(), key=lambda s: float(s.split('=')[1])):
        raw_qs   = sorted(lifetimes[wr].keys(), key=lambda q: float(q.split('=')[1]))
        clean_qs = [q.split('=')[1] for q in raw_qs]

        idx = pd.MultiIndex.from_product([models, clean_qs],
                                         names=['Model','q [m/s]'])
        df  = pd.DataFrame(index=idx, columns=directions, dtype=object)

        for raw_q, clean_q in zip(raw_qs, clean_qs):
            for model in models:
                dir_dict = lifetimes[wr][raw_q].get(model, {})
                for d in directions:
                    val = dir_dict.get(d, pd.NA)
                    if pd.notna(val):
                        df.at[(model, clean_q), d] = int(val)

        # replace missing for q>0
        for (model, qv), row in df.iterrows():
            if qv != '0':
                for d in directions:
                    if pd.isna(row[d]):
                        df.at[(model, qv), d] = "Not Reached"
            else:
                # for q=0, leave missing as blank
                for d in directions:
                    if pd.isna(row[d]):
                        df.at[(model, qv), d] = ""
        df.rename(columns={d: f"Direction: {d}" for d in directions},
                  inplace=True)
        wr_val  = wr.split('=')[1]
        caption = f"Well rate: {wr_val} m³/day"
        styler = (df.style
                    .set_caption(caption)
                    .set_table_styles([{
                        'selector': 'caption',
                        'props': [
                            ('caption-side', 'top'),
                            ('font-size', '14px'),
                            ('font-weight', 'bold')
                        ]
                    }])
                 )
        display(styler)

def compare_normalized(data, q1, wr1, q2, wr2, x_limits: tuple[float,float]=None):
    lifetimes = compute_lifetimes(data)
    for wr in (wr1, wr2):
        if wr == 'WR=4000':
            lifetimes[wr]['q=0']['homogeneous']['0'] = 102
            lifetimes[wr]['q=0']['model 4']['0']    = 122

    models = ['homogeneous','model 0','model 1','model 2','model 3','model 4']
    fig, axes = plt.subplots(3,2,figsize=(14,11), sharey=True)
    axes = axes.flatten()

    angles = [0,45,90,135,180,225,270,315]
    tab10  = plt.get_cmap('tab10').colors
    cmap_map = {a:tab10[i] for i,a in enumerate(angles)}

    base_key = 'q=0'
    for ax, model in zip(axes, models):
        L1 = lifetimes[wr1][base_key][model]['0']
        L2 = lifetimes[wr2][base_key][model]['0']
        if np.isnan(L1) or np.isnan(L2):
            ax.text(0.5,0.5,"Missing lifetime",ha='center')
            ax.set_title(model)
            continue

        # scenario1 solid
        df0 = data[model][(base_key,wr1)]
        t0, T0 = df0['time'].values, df0['PRD : temperature (K)'].values
        for (qk, wr), df in data[model].items():
            if wr==wr1 and qk.startswith(q1) and qk!='q=0':
                angle = int(qk.split('dir=')[1])
                yrs = df['time'].values/365
                dT  = df['PRD : temperature (K)'].values - np.interp(df['time'],t0,T0)
                ax.plot(yrs/L1, dT, color=cmap_map[angle], linestyle='-')

        # scenario2 dashed
        df0 = data[model][(base_key,wr2)]
        t0, T0 = df0['time'].values, df0['PRD : temperature (K)'].values
        for (qk, wr), df in data[model].items():
            if wr==wr2 and qk.startswith(q2) and qk!='q=0':
                angle = int(qk.split('dir=')[1])
                yrs = df['time'].values/365
                dT  = df['PRD : temperature (K)'].values - np.interp(df['time'],t0,T0)
                ax.plot(yrs/L2, dT, color=cmap_map[angle], linestyle='--')

        if x_limits is not None:
            ax.set_xlim(*x_limits)

        ax.set_title(f"{model}\nL₁={int(L1)}y, L₂={int(L2)}y")
        ax.set_xlabel('t / lifetime')
        ax.grid(True)

    ylabel = r'$\Delta T$ (K) relative to q=0' 
    fig.text(0.005, 0.5, ylabel, va='center', rotation='vertical')
    fig.suptitle(f"Comparison of Production Temperature Differences vs Normalized Time",fontsize=14)

    style_handles = [
        Line2D([0],[0],color='black',linestyle='-',lw=2),
        Line2D([0],[0],color='black',linestyle='--',lw=2),
    ]

    #m/s to m/day
    q_map = {
    'q=2.3e-08': 'q=0.002',
    'q=2.3e-07': 'q=0.020',
    'q=1.15e-07': 'q=0.010',
    'q=3.1e-07': 'q=0.027',}

    q1_new = q_map.get(q1, q1)
    q2_new = q_map.get(q2, q2)

    style_labels = [f"{q1_new}, {wr1} (1)", f"{q2_new}, {wr2} (2)"]

    color_handles = []
    color_labels  = []
    for angle in angles:
        proxy = Line2D([0],[0],color=cmap_map[angle],lw=4)
        color_handles.append(proxy)
        color_labels.append(f"dir={angle}")

    handles = style_handles + color_handles
    labels  = style_labels  + color_labels

    fig.legend(handles, labels, title="Scenario & Direction", loc="center left", bbox_to_anchor=(0.92,0.5), ncol=1, fontsize='small', borderaxespad=0)
    plt.tight_layout(rect=[0,0,0.88,0.93])
    plt.show()


def compare_normalized_vertical(data, q1, wr1, q2, wr2, x_limits: tuple[float,float]=None):
    lifetimes = compute_lifetimes(data)
    for wr in (wr1, wr2):                                                #REMOVE
        if wr=='WR=4000':
            lifetimes[wr]['q=0']['homogeneous']['0']=102
            lifetimes[wr]['q=0']['model 4']['0']=122

    models = ['homogeneous','model 0','model 1','model 2','model 3','model 4']
    fig, axes = plt.subplots(len(models),1,figsize=(14,25),sharex=False,sharey=True)

    angles = [0,45,90,135,180,225,270,315]
    tab10   = plt.get_cmap('tab10').colors
    cmap_map = {a:tab10[i] for i,a in enumerate(angles)}

    base_key = 'q=0'
    for ax, model in zip(axes, models):
        L1 = lifetimes[wr1][base_key][model]['0']
        L2 = lifetimes[wr2][base_key][model]['0']
        if np.isnan(L1) or np.isnan(L2):
            ax.text(0.5,0.5,"Missing lifetime",ha='center')
            ax.set_title(model)
            continue

        # solid
        df0 = data[model][(base_key,wr1)]
        t0,T0 = df0['time'].values, df0['PRD : temperature (K)'].values
        for (qk,wr),df in data[model].items():
            if wr==wr1 and qk.startswith(q1) and qk!='q=0':
                angle=int(qk.split('dir=')[1])
                yrs=df['time'].values/365
                dT=df['PRD : temperature (K)'].values - np.interp(df['time'],t0,T0)
                ax.plot(yrs/L1,dT,color=cmap_map[angle],linestyle='-')

        # dashed
        df0 = data[model][(base_key,wr2)]
        t0,T0 = df0['time'].values, df0['PRD : temperature (K)'].values
        for (qk,wr),df in data[model].items():
            if wr==wr2 and qk.startswith(q2) and qk!='q=0':
                angle=int(qk.split('dir=')[1])
                yrs=df['time'].values/365
                dT=df['PRD : temperature (K)'].values - np.interp(df['time'],t0,T0)
                ax.plot(yrs/L2,dT,color=cmap_map[angle],linestyle='--')

        if x_limits is not None:
            ax.set_xlim(*x_limits)

        ax.set_title(f"{model}  (L₁={int(L1)}y, L₂={int(L2)}y)")
        ax.set_ylabel(r'$\Delta T$ (K) relative to q=0' )
        ax.grid(True)

        style_handles = [
            Line2D([0],[0],color='black',linestyle='-',lw=2),
            Line2D([0],[0],color='black',linestyle='--',lw=2),
        ]
        style_labels = [f"{q1}, {wr1} (1)", f"{q2}, {wr2} (2)"]

        color_handles = []
        color_labels  = []
        for angle in angles:
            p = Line2D([0],[0],color=cmap_map[angle],lw=4)
            color_handles.append(p)
            color_labels.append(f"dir={angle}")

        ax.legend(style_handles+color_handles,style_labels+color_labels,title="Scenario & Direction",loc="upper left",bbox_to_anchor=(1.02,1),ncol=1,fontsize='small',borderaxespad=0)

    axes[-1].set_xlabel('t / lifetime')
    fig.suptitle(f"Comparison of Production Temperature Differences vs Normalized Time", fontsize=16)
    plt.tight_layout(rect=[0,0,0.85,0.93])
    plt.show()

# %%
from matplotlib.lines import Line2D
import numpy as np
import matplotlib.pyplot as plt

def _parse_q_key(qk):
    if qk is None:
        return (np.inf, None)
    parts = [p.strip() for p in qk.split(',')]
    q_part = parts[0]
    try:
        q_val = float(q_part.split('=')[1])
    except Exception:
        q_val = np.inf
    dir_val = None
    if len(parts) > 1 and 'dir=' in parts[1]:
        try:
            dir_val = int(parts[1].split('=')[1])
        except Exception:
            dir_val = None
    return (q_val, dir_val)

def _legend_sort_key(qk):
    qval, d = _parse_q_key(qk)
    return (qval if not np.isnan(qval) else np.inf, -1 if d is None else d)

def plot_single(data, q_value, well_rate, model_name,
                diff: bool = False, x_limits: tuple[float,float]=None,
                y_limits: tuple[float,float]=None):
    """
    Plot single model subplot with the same look as the multi-panel collection plot.

    :param data: dictionary returned by load_data(...)
    :param q_value: string e.g. 'q=2.3e-07' (base_key = 'q=0' used for reference)
    :param well_rate: string e.g. 'WR=8000'
    :param model_name: which model to plot e.g. 'homogeneous' or 'model 1'
    :param diff: if True, plot difference relative to q=0 (q=0 must exist in series)
    :param x_limits: optional x axis limits (years), tuple (xmin, xmax)
    :param y_limits: optional y axis limits, tuple (ymin, ymax)
    """
    base_key = 'q=0'

    angle_groups = [[0], [45,315], [90,270], [135,225], [180]]
    tab10 = plt.get_cmap('tab10').colors
    group_colors = tab10[:5]
    style_map = {}
    for idx, grp in enumerate(angle_groups):
        col = group_colors[idx]
        for a in grp:
            style_map[a] = (col, '-')
    for a in [315,270,225,180]:
        c,_ = style_map[a]
        style_map[a] = (c, '--')

    dd = data.get(model_name, {})
    series = { qk:df for (qk, wr), df in dd.items() if wr == well_rate }

    if len(series) == 0:
        raise ValueError(f"No series found for model={model_name}, well_rate={well_rate}")

    if diff:
        if base_key not in series:
            raise ValueError("diff=True but baseline 'q=0' not present for this model/well_rate")
        df0 = series[base_key]
        t0 = df0['time'].values
        T0 = df0['PRD : temperature (K)'].values

    fig, ax = plt.subplots(figsize=(8,5))

    for qk in sorted(series.keys(), key=_legend_sort_key):
        if diff:
            if qk == base_key or not qk.startswith(q_value):
                continue
        else:
            if not (qk == base_key or qk.startswith(q_value)):
                continue

        df = series[qk]
        t_years = df['time'].values / 365.0
        y = df['PRD : temperature (K)'].values

        if qk == base_key and not diff:
            ax.plot(t_years, y, label=qk, linestyle='-.', color='black')
        else:
            _, d = _parse_q_key(qk)
            if d is None:
                col, ls = ('gray','-')
            else:
                col, ls = style_map.get(d, (tab10[0], '-'))

            if diff:
                y = y - np.interp(df['time'].values, t0, T0)

            ax.plot(t_years, y, label=qk, color=col, linestyle=ls)

    if x_limits is not None:
        ax.set_xlim(*x_limits)
    if y_limits is not None:
        ax.set_ylim(*y_limits)

    ax.set_title(model_name)
    ax.set_xlabel('Time (years)')
    ax.set_ylabel('PRD : temperature (K)' if not diff else r'$\Delta T$ (K) relative to q=0')
    ax.grid(True)

    handles, labels = ax.get_legend_handles_labels()
    hm = dict(zip(labels, handles))
    # m/s to m/day
    if q_value == 'q=2.3e-08':
        q_new = 'q=0.002'
    if q_value == 'q=2.3e-07':
        q_new = 'q=0.020'
    if q_value == 'q=1.15e-07':
        q_new = 'q=0.010'
    if q_value == 'q=3.1e-07':
        q_new = 'q=0.027'

    hm_converted = {}
    for k, v in hm.items():
        if k.startswith(q_value):
            hm_converted[k.replace(q_value, q_new)] = v
        else:
            hm_converted[k] = v

    hm = hm_converted
    
    left  = [
        f"{q_new}, dir=0",
        f"{q_new}, dir=45",
        f"{q_new}, dir=90",
        f"{q_new}, dir=135",
        "" if diff else "q=0"
    ]
    right = [
        "",
        f"{q_new}, dir=315",
        f"{q_new}, dir=270",
        f"{q_new}, dir=225",
        f"{q_new}, dir=180"
    ]
    blank = Line2D([],[],linestyle='none',color='none')
    lh, ll = [], []
    for lab in left + right:
        if lab:
            lh.append(hm.get(lab, blank))
            ll.append(lab)
        else:
            lh.append(blank)
            ll.append("")

    fig.legend(
        lh, ll,
        title='Background flowrate, direction',
        ncol=2,
        loc='center left',
        bbox_to_anchor=(0.92,0.5),
        borderaxespad=0.0,
        handlelength=2,
        handletextpad=0.5
    )

    if not diff:
        kind = 'PRD : Temperature'
    else:
        kind = 'PRD : Temperature Difference'
    fig.suptitle(f"{kind} vs Time: {q_new} m/day, {well_rate} m³/day", fontsize=14)
    fig.tight_layout(rect=[0.05,0.05,0.88,0.93])
    plt.show()

# %%
PRD_data = load_data('output', 'Production_old')
REC_data = load_data('output', 'Recharge')
REC_test_data = load_data('output', 'Recharge test')

# %%
plot_single(PRD_data, q_value='q=2.3e-07', well_rate='WR=8000', model_name='homogeneous', diff=False, x_limits=(0,100), y_limits=(325, 355))
plot_single(PRD_data, q_value='q=2.3e-07', well_rate='WR=8000', model_name='homogeneous', diff=True, x_limits=(0,100), y_limits=(-10, 8))
plot_single(PRD_data, q_value='q=2.3e-07', well_rate='WR=8000', model_name='model 0', diff=False, x_limits=(0,100), y_limits=(325, 355))
plot_single(PRD_data, q_value='q=2.3e-07', well_rate='WR=8000', model_name='model 0', diff=True, x_limits=(0,100), y_limits=(-10, 8))
plot_single(PRD_data, q_value='q=2.3e-07', well_rate='WR=8000', model_name='model 1', diff=False, x_limits=(0,100), y_limits=(325, 355))
plot_single(PRD_data, q_value='q=2.3e-07', well_rate='WR=8000', model_name='model 1', diff=True, x_limits=(0,100), y_limits=(-10, 8))
plot_single(PRD_data, q_value='q=2.3e-07', well_rate='WR=8000', model_name='model 2', diff=False, x_limits=(0,100), y_limits=(325, 355))
plot_single(PRD_data, q_value='q=2.3e-07', well_rate='WR=8000', model_name='model 2', diff=True, x_limits=(0,100), y_limits=(-10, 8))
plot_single(PRD_data, q_value='q=2.3e-07', well_rate='WR=8000', model_name='model 3', diff=False, x_limits=(0,100), y_limits=(325, 355))
plot_single(PRD_data, q_value='q=2.3e-07', well_rate='WR=8000', model_name='model 3', diff=True, x_limits=(0,100), y_limits=(-10, 8))
plot_single(PRD_data, q_value='q=2.3e-07', well_rate='WR=8000', model_name='model 4', diff=False, x_limits=(0,100), y_limits=(325, 355))
plot_single(PRD_data, q_value='q=2.3e-07', well_rate='WR=8000', model_name='model 4', diff=True, x_limits=(0,100), y_limits=(-10, 8))

# %%
plot_collection(PRD_data, 'q=2.3e-08', 'WR=8000', diff=False, x_limits=(0,100))
plot_collection(PRD_data, 'q=2.3e-07', 'WR=8000', diff=False, x_limits=(0,100))
plot_collection(PRD_data, 'q=1.15e-07', 'WR=4000', diff=False, x_limits=(0,100))
plot_collection(PRD_data, 'q=3.1e-07', 'WR=8000', diff=False, x_limits=(0,100))

# %%
plot_collection(PRD_data, 'q=2.3e-08', 'WR=8000', diff=True, x_limits=(0,100))
plot_collection(PRD_data, 'q=2.3e-07', 'WR=8000', diff=True, x_limits=(0,100))
plot_collection(PRD_data, 'q=1.15e-07', 'WR=4000', diff=True, x_limits=(0,100))
plot_collection(PRD_data, 'q=3.1e-07', 'WR=8000', diff=True, x_limits=(0,100))

# %%
lifetime_tables(REC_data)
# Out:
# <style type="text/css">
# #T_2c647 caption {
#   caption-side: top;
#   font-size: 14px;
#   font-weight: bold;
# }
# </style>
# <table id="T_2c647">
#   <caption>Well rate: 4000 m³/day</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c647_level0_col0" class="col_heading level0 col0" >Direction: 0</th>
#       <th id="T_2c647_level0_col1" class="col_heading level0 col1" >Direction: 45</th>
#       <th id="T_2c647_level0_col2" class="col_heading level0 col2" >Direction: 90</th>
#       <th id="T_2c647_level0_col3" class="col_heading level0 col3" >Direction: 135</th>
#       <th id="T_2c647_level0_col4" class="col_heading level0 col4" >Direction: 180</th>
#       <th id="T_2c647_level0_col5" class="col_heading level0 col5" >Direction: 225</th>
#       <th id="T_2c647_level0_col6" class="col_heading level0 col6" >Direction: 270</th>
# ...

# %%
compare_normalized(
  PRD_data,
  q1='q=2.3e-07', wr1='WR=8000',
  q2='q=1.15e-07', wr2='WR=4000',
  x_limits=(0,1)
)

# %%
plot_collection(REC_data, 'q=2.3e-08', 'WR=8000', diff=False, x_limits=(0,0.000020))
plot_collection(REC_data, 'q=1.15e-07', 'WR=4000', diff=False, x_limits=(0,200))
plot_collection(REC_data, 'q=2.3e-07', 'WR=8000', diff=False, x_limits=(0,200))
plot_collection(REC_data, 'q=2.07e-07', 'WR=8000', diff=False, x_limits=(0,200))

# %%
def plot_recharge(data, q_value, well_rate, col, x_limits: tuple[float,float]=None):
    models   = ['homogeneous','model 0','model 1','model 2','model 3','model 4']
    fig, axes = plt.subplots(3,2,figsize=(14,11), sharex=False, sharey=True)
    axes = axes.flatten()
    base_key = 'q=0'

    angle_groups = [
        [0], [45,315], [90,270], [135,225], [180]
    ]
    tab10 = plt.get_cmap('tab10').colors
    group_colors = tab10[:5]
    style_map = {}
    for idx, grp in enumerate(angle_groups):
        clr = group_colors[idx]
        for a in grp:
            style_map[a] = (clr, '-')
    for a in [315,270,225,180]:
        c,_ = style_map[a]
        style_map[a] = (c, '--')

    for ax, model in zip(axes, models):
        series = {
            qk:df for (qk,wr),df in data.get(model, {}).items()
            if wr == well_rate
        }

        for qk in sorted(series, key=legend_sort):
            if not (qk == base_key or qk.startswith(q_value)):
                    continue

            df = series[qk]
            T0 = df['PRD : temperature (K)'].iloc[0]
            thresh = T0 - 0.15 * (T0 - 300)
            mask = df['PRD : temperature (K)'] <= thresh
            idx0 = mask.idxmax()  # first True index
            t_thresh = df.loc[idx0, 'time']
            t  = df['time'].values
            t_rec = (t - t_thresh) / 365.0
            y  = df[col].values  #y  = df['PRD : temperature (K)'].values
            if qk == base_key:
                ax.plot(t_rec, y, label=qk,
                        linestyle='-.', color='black')
            else:
                angle = int(qk.split('dir=')[1])
                clr, ls = style_map[angle]
                ax.plot(t_rec, y, label=qk,
                        color=clr, linestyle=ls)

        if x_limits is not None:
            ax.set_xlim(*x_limits)

        ax.set_title(model)
        ax.grid(True)

    handles, labels = axes[0].get_legend_handles_labels()
    hm = dict(zip(labels, handles))
    left  = [
        f"{q_value}, dir=0",
        f"{q_value}, dir=45",
        f"{q_value}, dir=90",
        f"{q_value}, dir=135",
        "q=0"]
    right = [
        "",
        f"{q_value}, dir=315",
        f"{q_value}, dir=270",
        f"{q_value}, dir=225",
        f"{q_value}, dir=180"
    ]
    blank = Line2D([],[],linestyle='none',color='none')
    lh, ll = [], []
    for lab in left + right:
        if lab:
            lh.append(hm.get(lab, blank))
            ll.append(lab)
        else:
            lh.append(blank)
            ll.append("")

    fig.legend(
        lh, ll,
        title='Background flowrate, direction',
        ncol=2,
        loc='center left',
        bbox_to_anchor=(0.92,0.5),
        borderaxespad=0.0,
        handlelength=2,
        handletextpad=0.5
    )

    fig.suptitle(f"{col} vs Time: {q_value}, {well_rate}", fontsize=14)
    fig.text(0.5, 0.04, 'Time (years)', ha='center')
    ylabel = col
    fig.text(0.04, 0.5, ylabel, va='center', rotation='vertical')

    fig.tight_layout(rect=[0.05,0.05,0.88,0.93])
    plt.show()

# %%
plot_recharge(REC_data, q_value='q=2.3e-07', well_rate='WR=8000', col='PRD : temperature (K)', x_limits=(-20, 200))
plot_recharge(REC_data, q_value='q=2.3e-07', well_rate='WR=8000', col='PRD : BHP (bar)', x_limits=(-20, 200))
# plot_recharge(REC_test_data, q_value='q=2.3e-07', well_rate='WR=8000', col='PRD : temperature (K)', x_limits=(-10, 10))
# plot_recharge(REC_test_data, q_value='q=2.3e-07', well_rate='WR=8000', col='PRD : BHP (bar)', x_limits=(-10, 10))

plot_recharge(REC_data, q_value='q=2.3e-07', well_rate='WR=8000', col='INJ : temperature (K)', x_limits=(-10, 10))
plot_recharge(REC_data, q_value='q=2.3e-07', well_rate='WR=8000', col='INJ : BHP (bar)', x_limits=(-10, 10))
# plot_recharge(REC_test_data, q_value='q=2.3e-07', well_rate='WR=8000', col='INJ : temperature (K)', x_limits=(-10, 10))
# plot_recharge(REC_test_data, q_value='q=2.3e-07', well_rate='WR=8000', col='INJ : BHP (bar)', x_limits=(-10, 10))

# %%
def plot_inj_recharge(data, q_value, well_rate, x_limits: tuple[float,float]=None):
    models   = ['homogeneous','model 0','model 1','model 2','model 3','model 4']
    fig, axes = plt.subplots(3,2,figsize=(14,11), sharex=False, sharey=True)
    axes = axes.flatten()
    base_key = 'q=0'

    angle_groups = [
        [0], [45,315], [90,270], [135,225], [180]
    ]
    tab10 = plt.get_cmap('tab10').colors
    group_colors = tab10[:5]
    style_map = {}
    for idx, grp in enumerate(angle_groups):
        col = group_colors[idx]
        for a in grp:
            style_map[a] = (col, '-')
    for a in [315,270,225,180]:
        c,_ = style_map[a]
        style_map[a] = (c, '--')

    for ax, model in zip(axes, models):
        series = {
            qk:df for (qk,wr),df in data.get(model, {}).items()
            if wr == well_rate
        }

        for qk in sorted(series, key=legend_sort):
            if not (qk == base_key or qk.startswith(q_value)):
                    continue

            df = series[qk]
            T0 = df['PRD : temperature (K)'].iloc[0]
            thresh = T0 - 0.15 * (T0 - 300)
            mask = df['PRD : temperature (K)'] <= thresh
            idx0 = mask.idxmax()  # first True index
            t_thresh = df.loc[idx0, 'time']
            t  = df['time'].values
            t_rec = (t - t_thresh) / 365.0
            y  = df['INJ : temperature (K)'].values
            if qk == base_key:
                ax.plot(t_rec, y, label=qk,
                        linestyle='-.', color='black')
            else:
                angle = int(qk.split('dir=')[1])
                col, ls = style_map[angle]
                ax.plot(t_rec, y, label=qk,
                        color=col, linestyle=ls)

        if x_limits is not None:
            ax.set_xlim(*x_limits)

        ax.set_title(model)
        ax.grid(True)

    handles, labels = axes[0].get_legend_handles_labels()
    hm = dict(zip(labels, handles))
    left  = [
        f"{q_value}, dir=0",
        f"{q_value}, dir=45",
        f"{q_value}, dir=90",
        f"{q_value}, dir=135",
        "q=0"]
    right = [
        "",
        f"{q_value}, dir=315",
        f"{q_value}, dir=270",
        f"{q_value}, dir=225",
        f"{q_value}, dir=180"
    ]
    blank = Line2D([],[],linestyle='none',color='none')
    lh, ll = [], []
    for lab in left + right:
        if lab:
            lh.append(hm.get(lab, blank))
            ll.append(lab)
        else:
            lh.append(blank)
            ll.append("")

    fig.legend(
        lh, ll,
        title='Background flowrate, direction',
        ncol=2,
        loc='center left',
        bbox_to_anchor=(0.92,0.5),
        borderaxespad=0.0,
        handlelength=2,
        handletextpad=0.5
    )

    kind = 'INJ : temperature (K)'
    fig.suptitle(f"{kind} vs Time: {q_value}, {well_rate}", fontsize=14)
    fig.text(0.5, 0.04, 'Time (years)', ha='center')
    ylabel = 'INJ : temperature (K)'
    fig.text(0.04, 0.5, ylabel, va='center', rotation='vertical')

    fig.tight_layout(rect=[0.05,0.05,0.88,0.93])
    plt.show()

# %%
plot_inj_recharge(REC_data, q_value='q=2.3e-07', well_rate='WR=8000', x_limits=(-2, 2))
plot_inj_recharge(REC_test_data, q_value='q=2.3e-07', well_rate='WR=8000', x_limits=(-2, 2))
